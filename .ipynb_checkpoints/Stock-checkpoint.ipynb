# %%
import math
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_percentage_error as mape
from sklearn.metrics import mean_squared_error as mse
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from pmdarima import auto_arima
from statsmodels.tools.eval_measures import rmse
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima.model import ARIMA

# %%
df = pd.read_csv('S&P500.csv', index_col='Date', parse_dates=True, usecols=['Date','Close'])
df=df.iloc[::-1]
split_size = int(0.8 * len(df))
test_data = df.iloc[split_size: , : ]
train_data = df.iloc[ :split_size, : ]

# %%
a = seasonal_decompose(df.Close, model = 'add')
a.plot();
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19224\4114464914.py in <module>
# ----> 1 a = seasonal_decompose(df.Close, model = 'add')
#       2 a.plot();
#
# E:\Anaconda\lib\site-packages\statsmodels\tsa\seasonal.py in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     140         pfreq = getattr(getattr(x, "index", None), "inferred_freq", None)
#     141
# --> 142     x = array_like(x, "x", maxdim=2)
#     143     nobs = len(x)
#     144
#
# E:\Anaconda\lib\site-packages\statsmodels\tools\validation\validation.py in array_like(obj, name, dtype, ndim, maxdim, shape, order, contiguous, optional)
#     133     if optional and obj is None:
#     134         return None
# --> 135     arr = np.asarray(obj, dtype=dtype, order=order)
#     136     if maxdim is not None:
#     137         if arr.ndim > maxdim:
#
# E:\Anaconda\lib\site-packages\pandas\core\series.py in __array__(self, dtype)
#     870               dtype='datetime64[ns]')
#     871         """
# --> 872         return np.asarray(self._values, dtype)
#     873
#     874     # ----------------------------------------------------------------------
#
# ValueError: could not convert string to float: '1,447.16'

# %%
plt.figure(figsize=(15,7))
a.seasonal.plot();
a.trend.plot();
a.resid.plot();

# %%
model_auto = auto_arima(df.Close)
parameter = model_auto.get_params().get('order')

# %%
arima_model = ARIMA(train_data.Close, order = parameter)
results = arima_model.fit()
results.summary()
# Out:
# E:\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\Anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# E:\Anaconda\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# E:\Anaconda\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 1168
# Model:               ARIMA(40, 1, 40)   Log Likelihood               -9791.914
# Date:                Fri, 18 Aug 2023   AIC                          19745.827
# Time:                        12:38:50   BIC                          20155.865
# Sample:                    12-10-2018   HQIC                         19900.497
#                          - 02-19-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.1087      6.097     -0.018      0.986     -12.058      11.841
# ar.L2          0.2767      5.309      0.052      0.958     -10.129      10.683
# ar.L3          0.2389      2.982      0.080      0.936      -5.606       6.084
# ar.L4         -0.0614      4.368     -0.014      0.989      -8.622       8.500
# ar.L5         -0.0779      4.402     -0.018      0.986      -8.707       8.551
# ar.L6          0.0652      3.607      0.018      0.986      -7.004       7.134
# ar.L7         -0.0247      2.987     -0.008      0.993      -5.880       5.830
# ar.L8          0.0558      2.630      0.021      0.983      -5.100       5.211
# ar.L9         -0.0330      2.154     -0.015      0.988      -4.255       4.189
# ar.L10         0.2447      1.815      0.135      0.893      -3.313       3.802
# ar.L11         0.0998      1.597      0.062      0.950      -3.031       3.231
# ar.L12        -0.2343      1.368     -0.171      0.864      -2.916       2.448
# ar.L13        -0.0510      1.805     -0.028      0.977      -3.588       3.486
# ar.L14        -0.0093      1.462     -0.006      0.995      -2.875       2.857
# ar.L15         0.1538      1.357      0.113      0.910      -2.507       2.814
# ar.L16         0.0151      1.772      0.008      0.993      -3.458       3.489
# ar.L17        -0.0676      1.588     -0.043      0.966      -3.179       3.044
# ar.L18        -0.0756      1.302     -0.058      0.954      -2.627       2.476
# ar.L19        -0.0718      1.385     -0.052      0.959      -2.786       2.643
# ar.L20        -0.0711      1.278     -0.056      0.956      -2.577       2.434
# ma.L26        -0.1192      1.223     -0.097      0.922      -2.517       2.278
# ma.L27        -0.0715      1.754     -0.041      0.967      -3.509       3.366
# ma.L28        -0.0052      1.371     -0.004      0.997      -2.691       2.681
# ma.L29        -0.1007      1.360     -0.074      0.941      -2.767       2.566
# ma.L30        -0.1591      0.878     -0.181      0.856      -1.880       1.562
# ma.L31        -0.0779      1.685     -0.046      0.963      -3.380       3.224
# ma.L32         0.1407      1.269      0.111      0.912      -2.347       2.628
# ma.L33         0.0340      0.518      0.066      0.948      -0.980       1.048
# ma.L34        -0.2431      0.624     -0.390      0.697      -1.465       0.979
# ma.L35        -0.1724      2.016     -0.085      0.932      -4.124       3.780
# ma.L36         0.3645      0.964      0.378      0.705      -1.525       2.254
# ma.L37         0.5273      1.455      0.363      0.717      -2.324       3.378
# ma.L38         0.0152      1.995      0.008      0.994      -3.895       3.925
# ma.L39        -0.2650      1.941     -0.137      0.891      -4.070       3.540
# ma.L40         0.0139      0.332      0.042      0.967      -0.638       0.665
# sigma2      1.287e+06   4.35e+04     29.585      0.000     1.2e+06    1.37e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):              1702.07
# Prob(Q):                              0.81   Prob(JB):                         0.00
# Heteroskedasticity (H):              25.23   Skew:                            -0.32
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.88
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
linear_preds = results.predict(start=len(train_data), end=len(df)-1, dynamic=True)
linear_preds
# Out:
# 2022-02-20    38256.786484
# 2022-02-21    37185.758830
# 2022-02-22    37089.496909
# 2022-02-23    37830.934203
# 2022-02-24    37788.919233
#                   ...
# 2022-12-05    37383.817464
# 2022-12-06    37389.700777
# 2022-12-07    37383.398167
# 2022-12-08    37410.948917
# 2022-12-09    37456.604302
# Freq: D, Name: predicted_mean, Length: 293, dtype: float64

# %%
test_data.Close.plot(figsize=(15,7), legend=True)
linear_preds.plot(legend=True)
# Out:
# <Axes: xlabel='Date'>

# %%
# arima_preds = []
# dummy = list(train_data.Close)
# dummy_test = list(test_data.Close)
# for i in range(len(test_data)):
#     dummy_model = ARIMA(dummy, order = parameter)
#     yhat = list(dummy_model.fit().forecast())
#     arima_preds.append(yhat)
#     dummy.append(dummy_test[i])

# %%
# plt.figure(figsize=(15,7))
# plt.plot(test_data[:30],label='Test Data')
# plt.grid(True)
# plt.plot(test_data[:30].index, arima_preds[:30],label='ARIMA Predictions')
# plt.xlabel("Time")
# plt.ylabel("Bitcoin Price")
# plt.legend(fontsize=10)
# plt.show()

# %%
# rmse_arima = rmse(test_data, arima_preds)
# rmse_arima[0]
# Out:
# 999.1072701649314

# %%
# mape_arima = mape(test_data, arima_preds)
# mape_arima*100
# Out:
# 2.4303491067620144

# %%
HORIZON = 1 
WINDOW_SIZE = 30

# %%
test_data = pd.concat([train_data[-WINDOW_SIZE:], test_data])
val_size = int(len(train_data) * 0.2)
validation_data = train_data[-val_size:]
train_data = train_data[:-val_size]

# %%
scaler = MinMaxScaler()
scaler.fit(train_data)
scaled_train_data = scaler.transform(train_data)
scaled_validation_data = scaler.transform(validation_data)
scaled_test_data = scaler.transform(test_data)

# %%
# residuals = pd.DataFrame(results.resid[1:])
# scaler.fit(residuals)
# residuals = scaler.transform(residuals)
# residuals

# %%
def get_labelled_windows(x, horizon=1):
    return x[:, :-horizon], x[:, -horizon:]

# %%
def make_windows(x, window_size=7, horizon=1):
    window_step = np.expand_dims(np.arange(window_size + horizon), axis = 0)
    window_indexes = window_step + np.expand_dims(np.arange(len(x) - (window_size + horizon - 1)), axis = 0).T
    windowed_array = x[window_indexes]
    windows, labels = get_labelled_windows(windowed_array, horizon=horizon)
    return windows, labels

# %%
train_windows, train_labels = make_windows(scaled_train_data, window_size=WINDOW_SIZE, horizon=HORIZON)
valid_windows, valid_labels = make_windows(scaled_validation_data, window_size=WINDOW_SIZE, horizon=HORIZON)
test_windows, test_labels = make_windows(scaled_test_data, window_size=WINDOW_SIZE, horizon=HORIZON)

# %%
train_windows.shape

# %%
from tensorflow import keras
from tensorflow.keras import layers
from kerastuner.tuners import RandomSearch

def build_model(hp):
    model = keras.Sequential()
    
    # Define the number of LSTM layers
    num_layers = hp.Int('num_layers', min_value=1, max_value=3)
    
    # Add LSTM layers
    for i in range(num_layers):
        model.add(layers.LSTM(units=hp.Choice(f'lstm_units_{i}', [32,64,128,256,512]),
                              return_sequences=(i != num_layers - 1),
                              input_shape=(WINDOW_SIZE,HORIZON)))
    
    model.add(layers.Dense(units=1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# Define the hyperparameter search space
tuner = RandomSearch(
    build_model,
    objective='val_loss',
    max_trials=30,
    executions_per_trial=1,
    directory='my_dir',
    project_name='original_tuning'
)

# Perform hyperparameter search
tuner.search(train_windows, train_labels, epochs=20, validation_data = (valid_windows, valid_labels))
tuner.results_summary()

# %%
# Get the best hyperparameters and evaluate on the validation set
best_hyperparameters = tuner.get_best_hyperparameters()[0]
best_model = tuner.hypermodel.build(best_hyperparameters)
history = best_model.fit(train_windows, train_labels, epochs=100, validation_data=(valid_windows, valid_labels))
val_loss_per_epoch = history.history['val_loss']
best_epoch = val_loss_per_epoch.index(min(val_loss_per_epoch)) + 1

# %%
best_model = tuner.hypermodel.build(best_hyperparameters)
# Retrain the model
history_best_model = best_model.fit(train_windows, train_labels, epochs=best_epoch, validation_data=(valid_windows, valid_labels))
best_model.summary()

# %%
pd.DataFrame(history_best_model.history).plot()

# %%
best_model.summary()

# %%
scaled_predictions = list()
batch = scaled_train_data[-WINDOW_SIZE:]
current_batch = batch.reshape((1,WINDOW_SIZE,1))

for i in range(293):
    pred = best_model.predict(current_batch)[0]
    scaled_predictions.append(pred)
    current_batch = np.append(current_batch[:,1:,:],[[pred]],axis=1)

predicted_prices = scaler.inverse_transform(np.array(scaled_predictions))

# %%
plt.figure(figsize=(15,7))
plt.plot(test_data[WINDOW_SIZE:],label='Test')
plt.grid(True)
plt.plot(test_data[WINDOW_SIZE:].index, predicted_prices,label='Predictions')
plt.xlabel("Time")
plt.ylabel("Bitcoin Price")
plt.legend(fontsize=10)
plt.show()

# %%
best_model_preds = best_model.predict(test_windows)
best_model_preds = scaler.inverse_transform(best_model_preds)

# %%
plt.figure(figsize=(15,7))
plt.plot(test_data[WINDOW_SIZE:2*WINDOW_SIZE],label='Test')
plt.grid(True)
plt.plot(test_data[WINDOW_SIZE:2*WINDOW_SIZE].index, best_model_preds[1:WINDOW_SIZE+1],label='Predictions')
plt.xlabel("Time")
plt.ylabel("Bitcoin Price")
plt.legend(fontsize=10)
plt.show()
